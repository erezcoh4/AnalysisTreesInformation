# %%
import sys; sys.path.insert(0, '../');
from ccqe_notebook_tools import *
# %matplotlib inline
# %matplotlib notebook

# %%
File = ROOT.TFile("/Users/erezcohen/Desktop/uBoone/AnalysisTreesAna/TracksAnaFiles/Events_MCC7_openCOSMIC_MC_AnalysisTrees.root")
tree = File.Get("eventsTree")
OpenCosmicMC  = calcEventTopologies( tree , "" )

# %%
Ntracks, tracks = get_event_from_rse(  events=OpenCosmicMC, run=1 , subrun=7279 , event=145580 )
draw_evd_tracks(tracks,MCmode=True, vertex_x=[60.45620],vertex_y=[7.77092],vertex_z=[997.8290])
