# %% [markdown]
# # my simplyfied event display from reconstructed track features

# %%
import sys; sys.path.insert(0, '../../'); sys.path.insert(0, '../');
from ccqe_notebook_tools import *
# %matplotlib inline
# %matplotlib notebook

# %% [markdown]
# # 2-tracks clusters

# %%
File = ROOT.TFile("/Users/erezcohen/Desktop/uBoone/AnalysisTreesAna/TracksAnaFiles/Events_MCC7_extBNB_AnalysisTrees.root")
tree = File.Get("eventsTree")
extBNB  = calcEventTopologies( tree , "" )

# %% [markdown]
# # a few cosmic (extBNB) 2-tracks clusters

# %%
Ntracks, tracks = get_event_from_rse( events=extBNB, run=5829 , subrun=40 , event=2016  )
draw_evd_tracks(tracks,MCmode=False,
                vertex_x=[169.2,84.2,182.8],
                vertex_y=[28.174,78.97,-84.28],
                vertex_z=[574.7,776.9,185.3])
plt.tight_layout()

# %% [markdown]
# # extBNB 2-tracks clusters that pass fiducial cuts and cfdistnace cuts

# %%
Ntracks, tracks = get_event_from_rse(  events=extBNB, run=5826 , subrun=67 , event=3381 )
draw_evd_tracks(tracks,MCmode=False, vertex_x=[218.9],vertex_y=[20.5],vertex_z=[405.7])

# %%
Ntracks, tracks = get_event_from_rse(  events=extBNB, run=5826 , subrun=46 , event=2325 )
draw_evd_tracks(tracks,MCmode=False, vertex_x=[89.3],vertex_y=[-13.23],vertex_z=[710.9])

# %%
Ntracks, tracks = get_event_from_rse(  events=extBNB, run=5826 , subrun=33 , event=1677 )
draw_evd_tracks(tracks,MCmode=False, vertex_x=[41.05],vertex_y=[-25.5],vertex_z=[329.7])

# %%
Ntracks, tracks = get_event_from_rse(  events=extBNB, run=5826 , subrun=34 , event=1727 )
draw_evd_tracks(tracks,MCmode=False, vertex_x=[135.3680],vertex_y=[38.19620],vertex_z=[526.0960])

# %%
Ntracks, tracks = get_event_from_rse(  events=extBNB, run=5832 , subrun=60 , event=3043 )
draw_evd_tracks(tracks,MCmode=False, vertex_x=[141.6350],vertex_y=[46.73790],vertex_z=[552.2730])

# %%
Ntracks, tracks = get_event_from_rse(  events=extBNB, run=5832 , subrun=62 , event=3101 )
draw_evd_tracks(tracks,MCmode=False, vertex_x=[151.6180],vertex_y=[-47.21470],vertex_z=[648.9390])
