# %%
import sys; sys.path.insert(0, '../');
from ccqe_notebook_tools import *
# %matplotlib inline
# %matplotlib notebook

# %%
File = ROOT.TFile("/Users/erezcohen/Desktop/uBoone/AnalysisTreesAna/TracksAnaFiles/Events_MCC7_MC_BNB_AnalysisTrees.root")
tree = File.Get("eventsTree")
events  = calcEventTopologies( tree )

# %% [markdown]
# # 'good' events
# 120	5	3256	65103	89.9883	-47.74910	691.924
# 134	4	1549	30980	31.9117	5.78528	271.509
# 135	5	2840	56798	125.7050	-12.11890	409.375
# 243	5	4371	87403	222.4440	37.24630	576.343
# 265	5	8194	163865	151.0310	-44.51550	338.0870
# 270	7	899	17970	133.1400	15.94720	373.2120
# 280	4	5478	109554	53.6772	-22.52690	755.0460
# 341	6	9120	182397	21.4835	87.88720	433.9130
# 366	4	3153	63046	210.3660	-80.82400	259.6800
# 382	5	1701	34014	140.1290	56.14830	777.2340
# 409	7	491	9806	124.5350	-72.44200	492.4160

# %% [markdown]
# # events that are not CC1p and pass all the cuts
# 88	6	678	13548	[13, 2212]	0	0	1	32767	143.90100	60.703800	61.0997
# 155	4	8286	165701	[13, 2212]	0	0	1	32767	92.04550	65.618100	984.2970
# 549	6	9387	187740	[13, 2212]	-1000	-1000	-1000	-1000	35.82550	83.596600	900.1110
# 990	7	1972	39421	[13, 2212]	-1000	-1000	-1000	-1000	109.58100	-17.152700	1000.8800
# 2644	5	2137	42731	[13, 2212]	0	0	1	32767	49.16470	73.819000	837.2140
# 3360	4	4379	87577	[2212, 13]	-1000	-1000	-1000	-1000	150.84500	3.661220	276.5940
# 4075	7	2764	55279	[13, 2212]	0	0	1	32767	182.80300	79.504000	796.4450
# 4158	6	4121	82412	[13, 2212]	-1000	-1000	-1000	-1000	40.43970	32.214300	920.0410
# 4161	7	4298	85944	[13, 2212]	-1000	-1000	-1000	-1000	156.61200	19.013600	14.4192
# 4355	5	6698	133942	[13, 2212]	0	0	1	32767	131.52900	52.025900	222.6640
# 5079	4	5677	113529	[13, 2212]	0	0	1	32767	13.50310	-16.263700	629.5820

# %%
Ntracks, tracks = get_event_from_rse(  events=events, run=6 , subrun=9387 , event=187740 )
draw_evd_tracks(tracks,MCmode=True, vertex_x=[35.8255],vertex_y=[83.596600],vertex_z=[900.1110])

# %%
Ntracks, tracks = get_event_from_rse(  events=events, run=5 , subrun=3848 , event=76943 )
draw_evd_tracks(tracks,MCmode=True, vertex_x=[221.261],vertex_y=[-70.1698],vertex_z=[170.757])

# %%
Ntracks, tracks = get_event_from_rse(  events=events, run=4 , subrun=4891 , event=97806 )
draw_evd_tracks(tracks,MCmode=True, vertex_x=[170.3800],vertex_y=[30.6028],vertex_z=[767.501])

# %%
Ntracks, tracks = get_event_from_rse(  events=events, run=4 , subrun=5478 , event=109554 )
draw_evd_tracks(tracks,MCmode=True, vertex_x=[124.535],vertex_y=[-22.5],vertex_z=[755.04])

# %%
Ntracks, tracks = get_event_from_rse(  events=events, run=7 , subrun=899 , event=17970 )
draw_evd_tracks(tracks,MCmode=True, vertex_x=[133.14],vertex_y=[15.94],vertex_z=[373.2])

# %%
Ntracks, tracks = get_event_from_rse(  events=events, run=5 , subrun=2840 , event=56798 )
draw_evd_tracks(tracks,MCmode=True, vertex_x=[125.7050],vertex_y=[-12.11890],vertex_z=[409.375])

# %%
Ntracks, tracks = get_event_from_rse(  events=events, run=4 , subrun=1549 , event=30980 )
draw_evd_tracks(tracks,MCmode=True, vertex_x=[31.9117],vertex_y=[5.78528],vertex_z=[271.509])

# %%
Ntracks, tracks = get_event_from_rse(  events=events, run=5 , subrun=3256 , event=65103 )
draw_evd_tracks(tracks,MCmode=True, vertex_x=[89.9883],vertex_y=[-47.7491],vertex_z=[691.924])
