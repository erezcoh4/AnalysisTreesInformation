# %% [markdown]
# # look for muons tracks that are reconstructed too-short
# from AnalysisTrees file (eventsTree)

# %%
import sys; sys.path.insert(0, '../');
from ccqe_notebook_tools import *
from tracking_tools import *
# %matplotlib notebook
# %matplotlib inline
from IPython.core.display import HTML,display
display(HTML("<style>.container { width:100% !important; }</style>"))
# redirect output to the systems standard output 
# sys.stdout = open('/dev/stdout', 'w')
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## MCC8 - MC-BNB + extBNB overlay

# %%
File = ROOT.TFile("/Users/erezcohen/Desktop/uBoone/AnalysisTreesAna/TracksAnaFiles/Events_MCC8_MC_BNB_extBNB_AnalysisTrees.root")
tree = File.Get("eventsTree")
analysistree = calcEventTopologies( tree )
# Out:
# TFile::Init:0: RuntimeWarning: no keys recovered, file has been made a Zombie
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-574b62fb906d> in <module>()
#       1 File = ROOT.TFile("/Users/erezcohen/Desktop/uBoone/AnalysisTreesAna/TracksAnaFiles/Events_MCC8_MC_BNB_extBNB_AnalysisTrees.root")
#       2 tree = File.Get("eventsTree")
# ----> 3 analysistree = calcEventTopologies( tree )
#
# TypeError: none of the 3 overloaded methods succeeded. Full details:
#   calcEventTopologies::calcEventTopologies(TTree* fInTree) =>
#     could not convert argument 1
#   calcEventTopologies::calcEventTopologies(const calcEventTopologies&) =>
#     could not convert argument 1
# ...

# %%
# %matplotlib inline
hits, tracks,i = find_next_event_with_a_muon_track( analysistree=analysistree , start_entry=0 ,debug=2 ) 
draw_evd_tracks(hits,tracks,do_add_PfromRange=True,xlim=[(500,900),(1000,1550),(1000,1800)], ylim=[(1850,2350),(1850,2350),(1850,2350)])
print i
# Out:
# 0.0%
# tracks.size(): 8
# hits.size(): 17040
# 8

# %%
hits, tracks,i = find_next_event_with_a_muon_track( analysistree=analysistree , start_entry=9 ,debug=0 ) 
draw_evd_tracks(hits,tracks,do_add_PfromRange=True,xlim=[(1800,3000),(1700,1900),(3000,3450)], ylim=[(3000,7000),(4700,5500),(4700,5500)])
print i
# Out:
# muon Ptruth=0.65 GeV/c, PfromRange=0.32 GeV/c (length=89.0 cm, truth start-end=235.1)
# muon Ptruth=0.65 GeV/c, PfromRange=0.32 GeV/c (length=89.0 cm, truth start-end=235.1)
# muon Ptruth=0.65 GeV/c, PfromRange=0.32 GeV/c (length=89.0 cm, truth start-end=235.1)
# 10

# %%
hits, tracks,i = find_next_event_with_a_muon_track( analysistree=analysistree , start_entry=11 ,debug=0 ) 
draw_evd_tracks(hits,tracks,do_add_PfromRange=True)
print i
# Out:
# 16

# %%
hits, tracks,i = find_next_event_with_a_muon_track( analysistree=analysistree , start_entry=17 ,debug=0 ) 
draw_evd_tracks(hits,tracks,do_add_PfromRange=True,xlim=[(1850,2200),(1650,2000),(2850,3500)], ylim=[(1230,1820),(1230,1820),(1230,1820)])
print i
# Out:
# muon Ptruth=0.83 GeV/c, PfromRange=0.42 GeV/c (length=137.2 cm, truth start-end=409.6)
# muon Ptruth=0.83 GeV/c, PfromRange=0.10 GeV/c (length=8.5 cm, truth start-end=409.6)
# muon Ptruth=0.83 GeV/c, PfromRange=0.42 GeV/c (length=137.2 cm, truth start-end=409.6)
# muon Ptruth=0.83 GeV/c, PfromRange=0.10 GeV/c (length=8.5 cm, truth start-end=409.6)
# muon Ptruth=0.83 GeV/c, PfromRange=0.42 GeV/c (length=137.2 cm, truth start-end=409.6)
# muon Ptruth=0.83 GeV/c, PfromRange=0.10 GeV/c (length=8.5 cm, truth start-end=409.6)
# 22

# %%
hits, tracks,i = find_next_event_with_a_muon_track( analysistree=analysistree , start_entry=23 ,debug=0 ) 
draw_evd_tracks(hits,tracks,do_add_PfromRange=True,xlim=[(1000,1900),(1450,2000),(1200,3170)], ylim=[(2100,3240),(2100,3240),(2100,3240)])
print i
# Out:
# muon Ptruth=0.89 GeV/c, PfromRange=0.51 GeV/c (length=179.6 cm, truth start-end=341.4)
# muon Ptruth=0.89 GeV/c, PfromRange=0.51 GeV/c (length=179.6 cm, truth start-end=341.4)
# muon Ptruth=0.89 GeV/c, PfromRange=0.51 GeV/c (length=179.6 cm, truth start-end=341.4)
# 24

# %%
hits, tracks,i = find_next_event_with_a_muon_track( analysistree=analysistree , start_entry=31 ,debug=0 ) 
draw_evd_tracks(hits,tracks,do_add_PfromRange=True)
print i
# Out:
# muon Ptruth=0.55 GeV/c, PfromRange=0.40 GeV/c (length=126.8 cm, truth start-end=804.0)
# muon Ptruth=0.55 GeV/c, PfromRange=0.29 GeV/c (length=77.5 cm, truth start-end=804.0)
# muon Ptruth=0.55 GeV/c, PfromRange=0.40 GeV/c (length=126.8 cm, truth start-end=804.0)
# muon Ptruth=0.55 GeV/c, PfromRange=0.29 GeV/c (length=77.5 cm, truth start-end=804.0)
# muon Ptruth=0.55 GeV/c, PfromRange=0.40 GeV/c (length=126.8 cm, truth start-end=804.0)
# muon Ptruth=0.55 GeV/c, PfromRange=0.29 GeV/c (length=77.5 cm, truth start-end=804.0)
# 33

# %% [markdown]
# ## MCC7 only MC-BNB

# %%
File = ROOT.TFile("/Users/erezcohen/Desktop/uBoone/AnalysisTreesAna/TracksAnaFiles/Events_MCC7_MC_BNB_AnalysisTrees.root")
tree = File.Get("eventsTree")
analysistree = calcEventTopologies( tree )

# %%
hits, tracks,i = find_next_event_with_a_muon_track( analysistree=analysistree , start_entry=0 ,debug=2 ) 
draw_evd_tracks(hits,tracks,do_add_PfromRange=True)
# Out:
# 0.0%
# tracks.size(): 3
# hits.size(): 1958
# muon Ptruth=0.96 GeV/c, PfromRange=0.66 GeV/c (length=244.5 cm, truth start-end=384.0)
# muon Ptruth=0.96 GeV/c, PfromRange=0.66 GeV/c (length=244.5 cm, truth start-end=384.0)
# muon Ptruth=0.96 GeV/c, PfromRange=0.66 GeV/c (length=244.5 cm, truth start-end=384.0)

# %%
hits, tracks,i = find_next_event_with_a_muon_track( analysistree=analysistree , start_entry=i+1 ,debug=2 ) 
draw_evd_tracks(hits,tracks,do_add_PfromRange=True)
# Out:
# tracks.size(): 4
# hits.size(): 1123

# %%
hits, tracks,i = find_next_event_with_a_muon_track( analysistree=analysistree , start_entry=i+1 ,debug=2 ) 
draw_evd_tracks(hits,tracks,do_add_PfromRange=True)
# Out:
# tracks.size(): 1
# hits.size(): 528
# muon Ptruth=0.62 GeV/c, PfromRange=0.31 GeV/c (length=85.7 cm, truth start-end=212.5)
# muon Ptruth=0.62 GeV/c, PfromRange=0.31 GeV/c (length=85.7 cm, truth start-end=212.5)
# muon Ptruth=0.62 GeV/c, PfromRange=0.31 GeV/c (length=85.7 cm, truth start-end=212.5)

# %%
hits, tracks,i = find_next_event_with_a_muon_track( analysistree=analysistree , start_entry=i+1 ,debug=2 ) 
draw_evd_tracks(hits,tracks,do_add_PfromRange=True)
# Out:
# tracks.size(): 1
# hits.size(): 1478

# %%
hits, tracks,i = find_next_event_with_a_muon_track( analysistree=analysistree , start_entry=i+1 ,debug=2 ) 
draw_evd_tracks(hits,tracks,do_add_PfromRange=True)
# Out:
# tracks.size(): 2
# hits.size(): 1005
# muon Ptruth=1.10 GeV/c, PfromRange=0.43 GeV/c (length=139.6 cm, truth start-end=763.0)
# muon Ptruth=1.10 GeV/c, PfromRange=0.43 GeV/c (length=139.6 cm, truth start-end=763.0)
# muon Ptruth=1.10 GeV/c, PfromRange=0.43 GeV/c (length=139.6 cm, truth start-end=763.0)

# %%
hits, tracks,i = find_next_event_with_a_muon_track( analysistree=analysistree , start_entry=i+1 ,debug=2 ) 
draw_evd_tracks(hits,tracks,do_add_PfromRange=True)
# Out:
# tracks.size(): 2
# hits.size(): 392
# muon Ptruth=0.40 GeV/c, PfromRange=0.26 GeV/c (length=63.6 cm, truth start-end=126.0)
# muon Ptruth=0.40 GeV/c, PfromRange=0.26 GeV/c (length=63.6 cm, truth start-end=126.0)
# muon Ptruth=0.40 GeV/c, PfromRange=0.26 GeV/c (length=63.6 cm, truth start-end=126.0)

# %%
hits, tracks,i = find_next_event_with_a_muon_track( analysistree=analysistree , start_entry=i+1 ,debug=2 ) 
draw_evd_tracks(hits,tracks,do_add_PfromRange=True)
print i
# Out:
# tracks.size(): 2
# hits.size(): 1895
# 38
