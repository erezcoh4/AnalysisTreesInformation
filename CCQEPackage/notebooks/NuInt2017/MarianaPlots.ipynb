# %%
import sys; sys.path.insert(0, '../');
from ccqe_notebook_tools import *
from tracking_tools import *
from scipy.optimize import curve_fit
# %matplotlib inline

# %% [markdown]
# ## Mariana multiplicity plot

# %%
proton_multiplicity = pd.DataFrame({'Np':[0,1,2,3,4],
                                  'Nevents':[331,217,38,0.400,0.010]})
pion_multiplicity = pd.DataFrame({'Npi':[0,1,2,3,4],
                                  'Nevents':[401,175,13,0,0]})

# %%
fig=plt.figure(figsize=(16,10))
ax=fig.add_subplot(1,2,1)
plt.bar(proton_multiplicity.Np-0.4,proton_multiplicity.Nevents)
set_axes(ax,'$N_p$','events$\\times 10^3$',fontsize=35,yticks=[0,100,200,300,400])
ax.set_xlim(-0.5,4.5)
ax.set_ylim(0,420)
ax=fig.add_subplot(1,2,2)
plt.bar(pion_multiplicity.Npi-0.4,pion_multiplicity.Nevents)
set_axes(ax,'$N_{\\pi}$','',fontsize=35,yticks=[0,100,200,300,400])
ax.set_xlim(-0.5,4.5)
ax.set_ylim(0,420)

plt.tight_layout()
