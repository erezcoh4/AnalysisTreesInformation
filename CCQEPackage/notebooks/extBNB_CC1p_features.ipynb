# %% [markdown]
# # analysis of truth-CC1p events

# %%
import sys; sys.path.insert(0, '../../AnaTreesPackage/notebooks')
from notebooks_tools import * 
# %matplotlib inline

# %% [markdown]
# # extBNB 2-track pairs

# %%
extBNB2tracks = pd.read_csv('/Users/erezcohen/Desktop/uBoone/analysis/ccqe_candidates/ccqe_candidates_CC1pTopology_MCC7_extBNB.csv',
                     converters={'track_id':generic,'distances':generic,'delta_phi':generic})
print len(extBNB2tracks),'extBNB 2-track vertices'
# Out:
# 13605 extBNB 2-track vertices

# %% [markdown]
# # plots to look for supressing contribution to CC1p search

# %%
fig,ax = plt.subplots(figsize=(16,9))
plot_2d_histogram(data=extBNB2tracks , varx='distance' , vary='delta_phi' ,fontsize=35,
                  x_label = 'rec. tracks distance [cm]', y_label='rec. $\\Delta \\phi$ [deg.]',
                  binsx=np.linspace(0,10,50), binsy=np.linspace(0,360,50), ax=ax , do_save_fig=False,
                  do_add_title=False)
ax.grid(linestyle='--',alpha=0.5)

# %%
fig,ax = plt.subplots(figsize=(16,9))
plot_2d_histogram(data=extBNB2tracks , varx='cosmicscore_long' , vary='cosmicscore_short' ,fontsize=35,
                  x_label = 'cosmic score (long track)', y_label='cosmic score (short track)',
                  ax=ax)
ax.grid(linestyle='--',alpha=0.5)

# %%
fig,ax = plt.subplots(figsize=(16,9))
plot_2d_histogram(data=extBNB2tracks , varx='starty_long' , vary='starty_short' ,fontsize=35,
                  x_label = 'cosmic score (long track)', y_label='cosmic score (short track)',
                  ax=ax)
ax.grid(linestyle='--',alpha=0.5)

# %%
fig,ax = plt.subplots(figsize=(16,9))
plot_2d_histogram(data=extBNB2tracks , varx='cfdistance_long' , vary='cfdistance_short' ,fontsize=35,
                  x_label = 'closest flash to short track [cm]', y_label='closest flash to long track [cm]',
                  binsx=np.linspace(-200,200,100), binsy=np.linspace(-200,200,100),
                  ax=ax)
ax.grid(linestyle='--',alpha=0.5)

# %%
fig,ax = plt.subplots(figsize=(16,9))
plt.plot([0,0],[100,100],linestyle='--',linewidth=3,color='blue')
plot_2d_histogram(data=extBNB2tracks , varx='PIDA_long' , vary='PIDA_short' ,fontsize=35,
                  x_label = 'rec. $PID_A^{long}$', y_label='rec. $PID_A^{short}$',
                  binsx=np.linspace(0,50,50), binsy=np.linspace(0,50,50), ax=ax , norm='non')
ax.grid(linestyle='--',which='both',alpha=0.5)

# %%
fig,ax = plt.subplots(figsize=(16,9))
plot_2d_histogram(data=extBNB2tracks , varx='l_long' , vary='l_short' ,fontsize=35,
                  x_label = 'rec. $l_{long}$ [cm]', y_label='rec. $l_{short}$ [cm]', 
                  binsx=np.linspace(0.1,100,100), binsy=np.linspace(0.1,100,100),
                  ax=ax)
ax.grid(linestyle='--',alpha=0.5)

# %%
fig,ax = plt.subplots(figsize=(16,9))
plot_2d_histogram(data=extBNB2tracks , varx='delta_theta' , vary='delta_phi' ,fontsize=35,
                  x_label = 'rec.  $\\Delta \\theta$ [deg.]', y_label='rec. $\\Delta \\phi$ [deg.]',
                  binsx=50, binsy=50, ax=ax)
ax.grid(linestyle='--',alpha=0.5)

# %%
fig,ax = plt.subplots(figsize=(16,9))
plot_2d_histogram(data=truthCC1p , varx='delta_theta' , vary='delta_phi' ,fontsize=35,
                  x_label = 'rec.  $\\Delta \\theta$ [deg.]', y_label='rec. $\\Delta \\phi$ [deg.]',
                  binsx=50, binsy=50, ax=ax)
ax.grid(linestyle='--',alpha=0.5)
