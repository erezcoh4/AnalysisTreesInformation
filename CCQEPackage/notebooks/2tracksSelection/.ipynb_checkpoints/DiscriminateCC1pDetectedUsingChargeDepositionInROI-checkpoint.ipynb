# %% [markdown]
# # Discriminate CC1p-detected from CC1p using charge deposition in ROI

# %%
import sys; sys.path.insert(0,'../'); 
from ccqe_notebook_tools import *
from tracking_tools import *
# %matplotlib inline
# redirect output to the systems standard output 
# sys.stdout = open('/dev/stdout', 'w')

# %% [markdown]
# from IPython.core.display import HTML,display
# display(HTML("<style>.container { width:100% !important; }</style>"))

# %%
File = ROOT.TFile("/Users/erezcohen/Desktop/uBoone/AnalysisTreesAna/TracksAnaFiles/Events_MCC7_MC_BNB_2TracksClusters.root")
tree = File.Get("TwoTracksTree")
events = AnalyzeVertex( tree )
# Out:
# TFile::Init:0: RuntimeWarning: file /Users/erezcohen/Desktop/uBoone/AnalysisTreesAna/TracksAnaFiles/Events_MCC7_MC_BNB_2TracksClusters.root probably not closed, trying to recover
# TFile::Init:0: RuntimeWarning: no keys recovered, file has been made a Zombie
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-bc6ac0f0e0de> in <module>()
#       1 File = ROOT.TFile("/Users/erezcohen/Desktop/uBoone/AnalysisTreesAna/TracksAnaFiles/Events_MCC7_MC_BNB_2TracksClusters.root")
#       2 tree = File.Get("TwoTracksTree")
# ----> 3 events = AnalyzeVertex( tree )
#
# TypeError: none of the 3 overloaded methods succeeded. Full details:
#   AnalyzeVertex::AnalyzeVertex() =>
#     takes at most 0 arguments (1 given)
#   AnalyzeVertex::AnalyzeVertex(TTree* fInTree) =>
#     could not convert argument 1
#   AnalyzeVertex::AnalyzeVertex(const AnalyzeVertex&) =>
#     could not convert argument 1

# %% [markdown]
# ## apply the method developed in AssociateHitsTracks for different samples

# %%
hits, vertex = get_CC1p_tracks_from_rse(events=events, run=6 , subrun=8579 , event=171568)
tracks = [vertex.AssignedMuonTrack , vertex.AssignedProtonTrack]
ratio = get_my_tracks_ratio_charge_in_roi( hits, tracks , debug=0 , planes=[0,1,2], do_plot=True , figsize=(16,10) )
# %timeit get_my_tracks_ratio_charge_in_roi( hits, tracks , debug=0, planes=[0,1,2] )
print ratio

# %%
debug = 1

if debug: print 'ratio_charge_true_cc1p'
ratio_charge_true_cc1p , ratio_charge_NonTrueCC1p1mu1p , ratio_charge_Non1mu1p = [] , [] , []
print 'looping over',events.Nentries,'entries'
for i in range(events.Nentries):
    if debug>1: print i
    if i%(events.Nentries/20)==0 or i%10==0: 
        print '%.0f'%(100.*float(i)/events.Nentries) + '%'
    hits, TwoTracksClusters = get_CC1p_tracks( events=events, i=i,  debug=debug )
    
    if debug>1: print TwoTracksClusters['Nclusters'],'2-tracks clusters'
    
    for i in range(TwoTracksClusters['Nclusters']):
        vertex = TwoTracksClusters['vertex %d'%i]
        run , subrun , event = vertex.run , vertex.subrun , vertex.event
        if debug: print run , subrun , event 
        
        tracks = [vertex.AssignedMuonTrack , vertex.AssignedProtonTrack]         
        ratio = get_my_tracks_ratio_charge_in_roi( hits, tracks , debug=debug )
        if ratio is np.nan: ratio=0

        if debug: ratio
        if vertex.GENIECC1p:
            ratio_charge_true_cc1p.append(ratio)
        elif vertex.Is1mu1pDetected:
            ratio_charge_NonTrueCC1p1mu1p.append(ratio)
        elif (tracks[0].MCpdgCode*tracks[1].MCpdgCode != 28756):
            ratio_charge_Non1mu1p.append(ratio)

print 'done.'
# Out:
# ratio_charge_true_cc1p
# looping over 654 entries
# 66
# 0 vertices 1 tracks 467 hits
# 0 2-tracks clusters
# 67
# 1 vertices 2 tracks 1404 hits
# 1 2-tracks clusters
# 6 8579 171568
# ratio_charge_per_plane: 0.732826166442
# ratio_charge_per_plane: 0.815589436796
# ratio_charge_per_plane: 0.784322155674
# charge_ratio_per_plane: [0.73282616644240195, 0.81558943679591733, 0.78432215567379449]
# 68
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 69
# 0 vertices 1 tracks 1998 hits
# 0 2-tracks clusters
# 70
# 11%
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 71
# 0 vertices 4 tracks 730 hits
# 0 2-tracks clusters
# 72
# 0 vertices 1 tracks 158 hits
# 0 2-tracks clusters
# 73
# 0 vertices 0 tracks 698 hits
# 0 2-tracks clusters
# 74
# 1 vertices 2 tracks 1456 hits
# 1 2-tracks clusters
# 6 8579 171575
# ratio_charge_per_plane: 0.577154739115
# ratio_charge_per_plane: 0.748394898573
# ratio_charge_per_plane: 0.644868136563
# charge_ratio_per_plane: [0.5771547391148143, 0.7483948985730301, 0.64486813656343456]
# 75
# 0 vertices 0 tracks 430 hits
# 0 2-tracks clusters
# 76
# 0 vertices 1 tracks 396 hits
# 0 2-tracks clusters
# 77
# 0 vertices 1 tracks 244 hits
# 0 2-tracks clusters
# 78
# 1 vertices 5 tracks 3928 hits
# 1 2-tracks clusters
# 6 8579 171579
# ratio_charge_per_plane: 0.626391080859
# ratio_charge_per_plane: 0.338671512089
# ratio_charge_per_plane: 0.701612977257
# charge_ratio_per_plane: [0.6263910808594263, 0.33867151208854568, 0.7016129772570997]
# 79
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 80
# 12%
# 0 vertices 1 tracks 152 hits
# 0 2-tracks clusters
# 81
# 0 vertices 0 tracks 5 hits
# 0 2-tracks clusters
# 82
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 83
# 0 vertices 0 tracks 152 hits
# 0 2-tracks clusters
# 84
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 85
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 86
# 0 vertices 0 tracks 44 hits
# 0 2-tracks clusters
# 87
# 0 vertices 2 tracks 527 hits
# 0 2-tracks clusters
# 88
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 89
# 0 vertices 0 tracks 146 hits
# 0 2-tracks clusters
# 90
# 14%
# 0 vertices 3 tracks 1878 hits
# 0 2-tracks clusters
# 91
# 0 vertices 3 tracks 3288 hits
# 0 2-tracks clusters
# 92
# 0 vertices 1 tracks 1340 hits
# 0 2-tracks clusters
# 93
# 0 vertices 1 tracks 4192 hits
# 0 2-tracks clusters
# 94
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 95
# 0 vertices 0 tracks 21 hits
# 0 2-tracks clusters
# 96
# 15%
# 0 vertices 2 tracks 579 hits
# 0 2-tracks clusters
# 97
# 0 vertices 4 tracks 1384 hits
# 0 2-tracks clusters
# 98
# 0 vertices 0 tracks 3 hits
# 0 2-tracks clusters
# 99
# 0 vertices 2 tracks 1111 hits
# 0 2-tracks clusters
# 100
# 15%
# 0 vertices 1 tracks 1319 hits
# 0 2-tracks clusters
# 101
# 0 vertices 1 tracks 267 hits
# 0 2-tracks clusters
# 102
# 0 vertices 0 tracks 197 hits
# 0 2-tracks clusters
# 103
# 0 vertices 1 tracks 1861 hits
# 0 2-tracks clusters
# 104
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 105
# 0 vertices 1 tracks 1706 hits
# 0 2-tracks clusters
# 106
# 0 vertices 0 tracks 17 hits
# 0 2-tracks clusters
# 107
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 108
# 0 vertices 0 tracks 206 hits
# 0 2-tracks clusters
# 109
# 0 vertices 0 tracks 1093 hits
# 0 2-tracks clusters
# 110
# 17%
# 1 vertices 3 tracks 469 hits
# 1 2-tracks clusters
# 7 4273 85451
# ratio_charge_per_plane: 0.795243569372
# ratio_charge_per_plane: 0.916495910802
# ratio_charge_per_plane: 0.886884789915
# charge_ratio_per_plane: [0.79524356937166651, 0.91649591080199455, 0.88688478991542607]
# 111
# 0 vertices 0 tracks 211 hits
# 0 2-tracks clusters
# 112
# 0 vertices 0 tracks 100 hits
# 0 2-tracks clusters
# 113
# 0 vertices 0 tracks 22 hits
# 0 2-tracks clusters
# 114
# 0 vertices 0 tracks 52 hits
# 0 2-tracks clusters
# 115
# 0 vertices 0 tracks 268 hits
# 0 2-tracks clusters
# 116
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 117
# 0 vertices 2 tracks 490 hits
# 0 2-tracks clusters
# 118
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 119
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 120
# 18%
# 0 vertices 3 tracks 901 hits
# 0 2-tracks clusters
# 121
# 0 vertices 1 tracks 649 hits
# 0 2-tracks clusters
# 122
# 0 vertices 1 tracks 188 hits
# 0 2-tracks clusters
# 123
# 0 vertices 3 tracks 675 hits
# 0 2-tracks clusters
# 124
# 0 vertices 0 tracks 8 hits
# 0 2-tracks clusters
# 125
# 0 vertices 1 tracks 193 hits
# 0 2-tracks clusters
# 126
# 0 vertices 0 tracks 13 hits
# 0 2-tracks clusters
# 127
# 0 vertices 0 tracks 102 hits
# 0 2-tracks clusters
# 128
# 20%
# 0 vertices 0 tracks 161 hits
# 0 2-tracks clusters
# 129
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 130
# 20%
# 0 vertices 0 tracks 153 hits
# 0 2-tracks clusters
# 131
# 0 vertices 0 tracks 7 hits
# 0 2-tracks clusters
# 132
# 0 vertices 0 tracks 171 hits
# 0 2-tracks clusters
# 133
# 0 vertices 0 tracks 2155 hits
# 0 2-tracks clusters
# 134
# 0 vertices 0 tracks 33 hits
# 0 2-tracks clusters
# 135
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 136
# 0 vertices 1 tracks 314 hits
# 0 2-tracks clusters
# 137
# 0 vertices 0 tracks 74 hits
# 0 2-tracks clusters
# 138
# 2 vertices 3 tracks 2038 hits
# 2 2-tracks clusters
# 5 2916 58319
# ratio_charge_per_plane: 0.866620572208
# ratio_charge_per_plane: 0.776858930868
# ratio_charge_per_plane: 0.861750304854
# charge_ratio_per_plane: [0.86662057220780742, 0.77685893086814006, 0.86175030485400739]
# 5 2916 58319
# ratio_charge_per_plane: 0.537200323907
# ratio_charge_per_plane: 0.607784954573
# ratio_charge_per_plane: 0.546472919068
# charge_ratio_per_plane: [0.53720032390749306, 0.60778495457335158, 0.54647291906801287]
# 139
# 0 vertices 1 tracks 224 hits
# 0 2-tracks clusters
# 140
# 21%
# 0 vertices 0 tracks 496 hits
# 0 2-tracks clusters
# 141
# 0 vertices 1 tracks 2318 hits
# 0 2-tracks clusters
# 142
# 0 vertices 0 tracks 34 hits
# 0 2-tracks clusters
# 143
# 0 vertices 0 tracks 57 hits
# 0 2-tracks clusters
# 144
# 0 vertices 2 tracks 784 hits
# 0 2-tracks clusters
# 145
# 0 vertices 1 tracks 168 hits
# 0 2-tracks clusters
# 146
# 0 vertices 0 tracks 2403 hits
# 0 2-tracks clusters
# 147
# 0 vertices 0 tracks 118 hits
# 0 2-tracks clusters
# 148
# 0 vertices 1 tracks 777 hits
# 0 2-tracks clusters
# 149
# 0 vertices 1 tracks 296 hits
# 0 2-tracks clusters
# 150
# 23%
# 2 vertices 4 tracks 2366 hits
# 2 2-tracks clusters
# 5 1834 36671
# ratio_charge_per_plane: 0.837055504333
# ratio_charge_per_plane: 0.577486410288
# ratio_charge_per_plane: 0.803631283379
# charge_ratio_per_plane: [0.83705550433286069, 0.57748641028779035, 0.80363128337895307]
# 5 1834 36671
# ratio_charge_per_plane: 0.890183637466
# ratio_charge_per_plane: 0.842231363267
# ratio_charge_per_plane: 0.902988509781
# charge_ratio_per_plane: [0.89018363746576123, 0.84223136326667836, 0.9029885097814685]
# 151
# 0 vertices 0 tracks 94 hits
# 0 2-tracks clusters
# 152
# 0 vertices 0 tracks 13 hits
# 0 2-tracks clusters
# 153
# 2 vertices 4 tracks 1288 hits
# 2 2-tracks clusters
# 5 1834 36674
# ratio_charge_per_plane: 0.771043269026
# ratio_charge_per_plane: 0.855197601825
# ratio_charge_per_plane: 0.772233119174
# charge_ratio_per_plane: [0.77104326902601339, 0.85519760182503912, 0.77223311917368898]
# 5 1834 36674
# ratio_charge_per_plane: 0.650928522316
# ratio_charge_per_plane: 0.96351878372
# ratio_charge_per_plane: 0.823733022637
# charge_ratio_per_plane: [0.65092852231605614, 0.96351878371951805, 0.82373302263674419]
# 154
# 1 vertices 2 tracks 2334 hits
# 1 2-tracks clusters
# 5 1834 36675
# ratio_charge_per_plane: 0.347799076384
# ratio_charge_per_plane: 0.747425150345
# ratio_charge_per_plane: 0.84023248554
# charge_ratio_per_plane: [0.34779907638425611, 0.74742515034463963, 0.84023248553969077]
# 155
# 0 vertices 1 tracks 1225 hits
# 0 2-tracks clusters
# 156
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 157
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 158
# 1 vertices 2 tracks 1679 hits
# 1 2-tracks clusters
# 5 1834 36679
# ratio_charge_per_plane: 0.953934776236
# ratio_charge_per_plane: 0.826916483648
# ratio_charge_per_plane: 0.971157478052
# charge_ratio_per_plane: [0.9539347762356376, 0.82691648364784287, 0.97115747805212327]
# 159
# 0 vertices 0 tracks 323 hits
# 0 2-tracks clusters
# 160
# 24%
# 0 vertices 0 tracks 36 hits
# 0 2-tracks clusters
# 161
# 0 vertices 0 tracks 8 hits
# 0 2-tracks clusters
# 162
# 0 vertices 1 tracks 301 hits
# 0 2-tracks clusters
# 163
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 164
# 2 vertices 3 tracks 391 hits
# 2 2-tracks clusters
# 1 2287 45725
# ratio_charge_per_plane: 0.941372528748
# ratio_charge_per_plane: 0.896154082435
# ratio_charge_per_plane: 0.921349320989
# charge_ratio_per_plane: [0.94137252874819566, 0.89615408243478856, 0.92134932098925215]
# 1 2287 45725
# ratio_charge_per_plane: 0.996609005145
# ratio_charge_per_plane: 1.0
# ratio_charge_per_plane: 0.983577074619
# charge_ratio_per_plane: [0.99660900514477746, 1.0, 0.9835770746191439]
# 165
# 0 vertices 1 tracks 1689 hits
# 0 2-tracks clusters
# 166
# 0 vertices 0 tracks 159 hits
# 0 2-tracks clusters
# 167
# 0 vertices 0 tracks 45 hits
# 0 2-tracks clusters
# 168
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 169
# 2 vertices 3 tracks 1054 hits
# 2 2-tracks clusters
# 1 2287 45730
# ratio_charge_per_plane: 0.970856672879
# ratio_charge_per_plane: 0.886823979577
# ratio_charge_per_plane: 0.9787674459
# charge_ratio_per_plane: [0.9708566728789505, 0.88682397957724246, 0.97876744589982623]
# 1 2287 45730
# ratio_charge_per_plane: 0.985116873318
# ratio_charge_per_plane: 0.781362649778
# ratio_charge_per_plane: 0.958959730567
# charge_ratio_per_plane: [0.98511687331844533, 0.78136264977809833, 0.95895973056724393]
# 170
# 26%
# 0 vertices 1 tracks 2652 hits
# 0 2-tracks clusters
# 171
# 0 vertices 2 tracks 2004 hits
# 0 2-tracks clusters
# 172
# 0 vertices 0 tracks 150 hits
# 0 2-tracks clusters
# 173
# 0 vertices 0 tracks 507 hits
# 0 2-tracks clusters
# 174
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 175
# 0 vertices 0 tracks 23 hits
# 0 2-tracks clusters
# 176
# 0 vertices 0 tracks 19 hits
# 0 2-tracks clusters
# 177
# 0 vertices 2 tracks 1645 hits
# 0 2-tracks clusters
# 178
# 0 vertices 1 tracks 23 hits
# 0 2-tracks clusters
# 179
# 0 vertices 2 tracks 436 hits
# 0 2-tracks clusters
# 180
# 28%
# 0 vertices 0 tracks 257 hits
# 0 2-tracks clusters
# 181
# 1 vertices 2 tracks 462 hits
# 1 2-tracks clusters
# 1 3853 77042
# ratio_charge_per_plane: 0.897495376849
# ratio_charge_per_plane: 0.943139513721
# ratio_charge_per_plane: 0.887995526207
# charge_ratio_per_plane: [0.89749537684870473, 0.94313951372144744, 0.88799552620695243]
# 182
# 0 vertices 0 tracks 7 hits
# 0 2-tracks clusters
# 183
# 1 vertices 3 tracks 1131 hits
# 1 2-tracks clusters
# 1 3853 77044
# ratio_charge_per_plane: 0.926777592635
# ratio_charge_per_plane: 0.989576481113
# ratio_charge_per_plane: 0.995615949151
# charge_ratio_per_plane: [0.92677759263539372, 0.98957648111262497, 0.99561594915120188]
# 184
# 0 vertices 0 tracks 153 hits
# 0 2-tracks clusters
# 185
# 0 vertices 2 tracks 352 hits
# 0 2-tracks clusters
# 186
# 0 vertices 0 tracks 353 hits
# 0 2-tracks clusters
# 187
# 1 vertices 2 tracks 793 hits
# 1 2-tracks clusters
# 1 3853 77048
# ratio_charge_per_plane: 0.925283417453
# ratio_charge_per_plane: 0.886596934992
# ratio_charge_per_plane: 0.771279576835
# charge_ratio_per_plane: [0.9252834174527117, 0.88659693499202963, 0.77127957683496484]
# 188
# 0 vertices 2 tracks 615 hits
# 0 2-tracks clusters
# 189
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 190
# 29%
# 0 vertices 1 tracks 1241 hits
# 0 2-tracks clusters
# 191
# 0 vertices 1 tracks 336 hits
# 0 2-tracks clusters
# 192
# 29%
# 0 vertices 0 tracks 629 hits
# 0 2-tracks clusters
# 193
# 0 vertices 1 tracks 531 hits
# 0 2-tracks clusters
# 194
# 0 vertices 1 tracks 753 hits
# 0 2-tracks clusters
# 195
# 0 vertices 0 tracks 525 hits
# 0 2-tracks clusters
# 196
# 0 vertices 0 tracks 29 hits
# 0 2-tracks clusters
# 197
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 198
# 0 vertices 0 tracks 2476 hits
# 0 2-tracks clusters
# 199
# 0 vertices 0 tracks 117 hits
# 0 2-tracks clusters
# 200
# 31%
# 0 vertices 0 tracks 621 hits
# 0 2-tracks clusters
# 201
# 0 vertices 1 tracks 125 hits
# 0 2-tracks clusters
# 202
# 0 vertices 0 tracks 7 hits
# 0 2-tracks clusters
# 203
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 204
# 0 vertices 0 tracks 11 hits
# 0 2-tracks clusters
# 205
# 0 vertices 2 tracks 205 hits
# 0 2-tracks clusters
# 206
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 207
# 0 vertices 1 tracks 947 hits
# 0 2-tracks clusters
# 208
# 0 vertices 0 tracks 60 hits
# 0 2-tracks clusters
# 209
# 0 vertices 0 tracks 128 hits
# 0 2-tracks clusters
# 210
# 32%
# 0 vertices 2 tracks 491 hits
# 0 2-tracks clusters
# 211
# 0 vertices 1 tracks 245 hits
# 0 2-tracks clusters
# 212
# 0 vertices 1 tracks 67 hits
# 0 2-tracks clusters
# 213
# 0 vertices 1 tracks 656 hits
# 0 2-tracks clusters
# 214
# 0 vertices 0 tracks 42 hits
# 0 2-tracks clusters
# 215
# 0 vertices 0 tracks 198 hits
# 0 2-tracks clusters
# 216
# 0 vertices 0 tracks 66 hits
# 0 2-tracks clusters
# 217
# 2 vertices 3 tracks 1157 hits
# 2 2-tracks clusters
# 6 4231 84618
# ratio_charge_per_plane: 0.294141427723
# ratio_charge_per_plane: 0.237763773308
# ratio_charge_per_plane: 0.24861467144
# charge_ratio_per_plane: [0.29414142772341306, 0.2377637733075379, 0.2486146714397689]
# 6 4231 84618
# ratio_charge_per_plane: 0.590963955241
# ratio_charge_per_plane: 0.935436986411
# ratio_charge_per_plane: 0.911454545558
# charge_ratio_per_plane: [0.59096395524107159, 0.93543698641062956, 0.91145454555774752]
# 218
# 0 vertices 0 tracks 563 hits
# 0 2-tracks clusters
# 219
# 0 vertices 1 tracks 598 hits
# 0 2-tracks clusters
# 220
# 34%
# 0 vertices 3 tracks 2732 hits
# 0 2-tracks clusters
# 221
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 222
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 223
# 0 vertices 2 tracks 370 hits
# 0 2-tracks clusters
# 224
# 34%
# 0 vertices 0 tracks 151 hits
# 0 2-tracks clusters
# 225
# 0 vertices 0 tracks 73 hits
# 0 2-tracks clusters
# 226
# 1 vertices 2 tracks 220 hits
# 1 2-tracks clusters
# 5 3928 78547
# ratio_charge_per_plane: 0.628580608005
# ratio_charge_per_plane: 0.633758570529
# ratio_charge_per_plane: 0.498701224889
# charge_ratio_per_plane: [0.62858060800503857, 0.63375857052912921, 0.49870122488875129]
# 227
# 0 vertices 0 tracks 97 hits
# 0 2-tracks clusters
# 228
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 229
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 230
# 35%
# 0 vertices 0 tracks 56 hits
# 0 2-tracks clusters
# 231
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 232
# 1 vertices 2 tracks 433 hits
# 1 2-tracks clusters
# 5 3928 78553
# ratio_charge_per_plane: 0.833619602891
# ratio_charge_per_plane: 0.924675182068
# ratio_charge_per_plane: 0.833695508879
# charge_ratio_per_plane: [0.8336196028914441, 0.92467518206782651, 0.83369550887912036]
# 233
# 0 vertices 0 tracks 11 hits
# 0 2-tracks clusters
# 234
# 0 vertices 0 tracks 57 hits
# 0 2-tracks clusters
# 235
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 236
# 1 vertices 2 tracks 336 hits
# 1 2-tracks clusters
# 5 3928 78557
# ratio_charge_per_plane: 0.454177310578
# ratio_charge_per_plane: 0.404105010736
# ratio_charge_per_plane: 0.439495657827
# charge_ratio_per_plane: [0.45417731057771554, 0.40410501073618138, 0.43949565782729216]
# 237
# 0 vertices 3 tracks 1910 hits
# 0 2-tracks clusters
# 238
# 0 vertices 0 tracks 121 hits
# 0 2-tracks clusters
# 239
# 0 vertices 2 tracks 4130 hits
# 0 2-tracks clusters
# 240
# 37%
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 241
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 242
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 243
# 0 vertices 0 tracks 17 hits
# 0 2-tracks clusters
# 244
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 245
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 246
# 0 vertices 1 tracks 1018 hits
# 0 2-tracks clusters
# 247
# 0 vertices 0 tracks 40 hits
# 0 2-tracks clusters
# 248
# 0 vertices 0 tracks 17 hits
# 0 2-tracks clusters
# 249
# 0 vertices 0 tracks 95 hits
# 0 2-tracks clusters
# 250
# 38%
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 251
# 0 vertices 0 tracks 30 hits
# 0 2-tracks clusters
# 252
# 0 vertices 0 tracks 65 hits
# 0 2-tracks clusters
# 253
# 0 vertices 0 tracks 190 hits
# 0 2-tracks clusters
# 254
# 0 vertices 0 tracks 8 hits
# 0 2-tracks clusters
# 255
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 256
# 39%
# 1 vertices 2 tracks 368 hits
# 1 2-tracks clusters
# 4 5114 102277
# ratio_charge_per_plane: 0.514028896577
# ratio_charge_per_plane: 0.79705983497
# ratio_charge_per_plane: 0.43650429998
# charge_ratio_per_plane: [0.51402889657698647, 0.7970598349700132, 0.43650429998040075]
# 257
# 0 vertices 0 tracks 223 hits
# 0 2-tracks clusters
# 258
# 0 vertices 0 tracks 2372 hits
# 0 2-tracks clusters
# 259
# 0 vertices 0 tracks 558 hits
# 0 2-tracks clusters
# 260
# 40%
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 261
# 0 vertices 0 tracks 174 hits
# 0 2-tracks clusters
# 262
# 0 vertices 1 tracks 262 hits
# 0 2-tracks clusters
# 263
# 0 vertices 0 tracks 380 hits
# 0 2-tracks clusters
# 264
# 0 vertices 2 tracks 1603 hits
# 0 2-tracks clusters
# 265
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 266
# 0 vertices 1 tracks 978 hits
# 0 2-tracks clusters
# 267
# 0 vertices 1 tracks 666 hits
# 0 2-tracks clusters
# 268
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 269
# 0 vertices 1 tracks 93 hits
# 0 2-tracks clusters
# 270
# 41%
# 1 vertices 3 tracks 1341 hits
# 1 2-tracks clusters
# 1 1214 24271
# ratio_charge_per_plane: 0.894720677194
# ratio_charge_per_plane: 0.69894370375
# ratio_charge_per_plane: 0.878052459633
# charge_ratio_per_plane: [0.89472067719411574, 0.69894370374950276, 0.87805245963260692]
# 271
# 0 vertices 0 tracks 207 hits
# 0 2-tracks clusters
# 272
# 0 vertices 1 tracks 218 hits
# 0 2-tracks clusters
# 273
# 0 vertices 0 tracks 127 hits
# 0 2-tracks clusters
# 274
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 275
# 0 vertices 0 tracks 18 hits
# 0 2-tracks clusters
# 276
# 0 vertices 0 tracks 64 hits
# 0 2-tracks clusters
# 277
# 0 vertices 0 tracks 1562 hits
# 0 2-tracks clusters
# 278
# 0 vertices 1 tracks 71 hits
# 0 2-tracks clusters
# 279
# 0 vertices 0 tracks 26 hits
# 0 2-tracks clusters
# 280
# 43%
# 0 vertices 2 tracks 1135 hits
# 0 2-tracks clusters
# 281
# 0 vertices 0 tracks 136 hits
# 0 2-tracks clusters
# 282
# 1 vertices 2 tracks 575 hits
# 1 2-tracks clusters
# 7 146 2903
# ratio_charge_per_plane: nan
# ratio_charge_per_plane: 0.725902719113
# ratio_charge_per_plane: 0.758581175189
# charge_ratio_per_plane: [nan, 0.72590271911271653, 0.75858117518906576]
# 283
# 0 vertices 0 tracks 439 hits
# 0 2-tracks clusters
# 284
# 3 vertices 7 tracks 3795 hits
# 3 2-tracks clusters
# 7 146 2905
# ratio_charge_per_plane: 0.339616468392
# ratio_charge_per_plane: 0.84565072643
# ratio_charge_per_plane: 0.805498205281
# charge_ratio_per_plane: [0.33961646839223375, 0.84565072642985128, 0.80549820528140925]
# 7 146 2905
# ratio_charge_per_plane: 0.820324825019
# ratio_charge_per_plane: 0.352234556362
# ratio_charge_per_plane: 0.782265800073
# charge_ratio_per_plane: [0.82032482501922843, 0.35223455636155604, 0.78226580007318802]
# 7 146 2905
# ratio_charge_per_plane: 0.723302401877
# ratio_charge_per_plane: 0.42925572553
# ratio_charge_per_plane: 0.38901380487
# charge_ratio_per_plane: [0.72330240187679973, 0.42925572552968727, 0.38901380486952497]
# 285
# 0 vertices 0 tracks 1016 hits
# 0 2-tracks clusters
# 286
# 0 vertices 2 tracks 524 hits
# 0 2-tracks clusters
# 287
# 0 vertices 0 tracks 3947 hits
# 0 2-tracks clusters
# 288
# 44%
# 0 vertices 0 tracks 209 hits
# 0 2-tracks clusters
# 289
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 290
# 44%
# 0 vertices 1 tracks 126 hits
# 0 2-tracks clusters
# 291
# 0 vertices 0 tracks 284 hits
# 0 2-tracks clusters
# 292
# 0 vertices 3 tracks 6002 hits
# 0 2-tracks clusters
# 293
# 0 vertices 2 tracks 941 hits
# 0 2-tracks clusters
# 294
# 0 vertices 1 tracks 518 hits
# 0 2-tracks clusters
# 295
# 0 vertices 0 tracks 1121 hits
# 0 2-tracks clusters
# 296
# 0 vertices 1 tracks 256 hits
# 0 2-tracks clusters
# 297
# 1 vertices 2 tracks 1073 hits
# 1 2-tracks clusters
# 7 146 2918
# ratio_charge_per_plane: 0.496101286765
# ratio_charge_per_plane: 0.850866673239
# ratio_charge_per_plane: 0.872796391248
# charge_ratio_per_plane: [0.49610128676533549, 0.85086667323918863, 0.87279639124811625]
# 298
# 0 vertices 0 tracks 156 hits
# 0 2-tracks clusters
# 299
# 0 vertices 0 tracks 29 hits
# 0 2-tracks clusters
# 300
# 46%
# 0 vertices 1 tracks 310 hits
# 0 2-tracks clusters
# 301
# 0 vertices 0 tracks 31 hits
# 0 2-tracks clusters
# 302
# 0 vertices 0 tracks 35 hits
# 0 2-tracks clusters
# 303
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 304
# 0 vertices 0 tracks 51 hits
# 0 2-tracks clusters
# 305
# 0 vertices 1 tracks 235 hits
# 0 2-tracks clusters
# 306
# 0 vertices 2 tracks 577 hits
# 0 2-tracks clusters
# 307
# 0 vertices 0 tracks 419 hits
# 0 2-tracks clusters
# 308
# 0 vertices 0 tracks 457 hits
# 0 2-tracks clusters
# 309
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 310
# 47%
# 0 vertices 0 tracks 23 hits
# 0 2-tracks clusters
# 311
# 1 vertices 3 tracks 1367 hits
# 1 2-tracks clusters
# 6 9532 190632
# ratio_charge_per_plane: 0.463316122712
# ratio_charge_per_plane: 0.319236299713
# ratio_charge_per_plane: 0.384224411733
# charge_ratio_per_plane: [0.46331612271236505, 0.31923629971250622, 0.38422441173339628]
# 312
# 0 vertices 2 tracks 706 hits
# 0 2-tracks clusters
# 313
# 0 vertices 1 tracks 876 hits
# 0 2-tracks clusters
# 314
# 0 vertices 0 tracks 71 hits
# 0 2-tracks clusters
# 315
# 0 vertices 0 tracks 70 hits
# 0 2-tracks clusters
# 316
# 1 vertices 3 tracks 1608 hits
# 1 2-tracks clusters
# 6 9532 190637
# ratio_charge_per_plane: 0.875879691259
# ratio_charge_per_plane: 0.366245591454
# ratio_charge_per_plane: 0.792419269989
# charge_ratio_per_plane: [0.87587969125863163, 0.36624559145366531, 0.79241926998932621]
# 317
# 0 vertices 1 tracks 773 hits
# 0 2-tracks clusters
# 318
# 0 vertices 0 tracks 21 hits
# 0 2-tracks clusters
# 319
# 0 vertices 0 tracks 78 hits
# 0 2-tracks clusters
# 320
# 49%
# 0 vertices 0 tracks 425 hits
# 0 2-tracks clusters
# 321
# 1 vertices 3 tracks 899 hits
# 1 2-tracks clusters
# 7 3585 71682
# ratio_charge_per_plane: 0.492855890374
# ratio_charge_per_plane: 0.551188367158
# ratio_charge_per_plane: 0.690281994845
# charge_ratio_per_plane: [0.49285589037427568, 0.55118836715825725, 0.69028199484491282]
# 322
# 1 vertices 2 tracks 1062 hits
# 1 2-tracks clusters
# 7 3585 71683
# ratio_charge_per_plane: 0.975057656211
# ratio_charge_per_plane: 0.944846392106
# ratio_charge_per_plane: 0.73978832876
# charge_ratio_per_plane: [0.97505765621095986, 0.94484639210580434, 0.73978832876029577]
# 323
# 0 vertices 2 tracks 1641 hits
# 0 2-tracks clusters
# 324
# 0 vertices 1 tracks 280 hits
# 0 2-tracks clusters
# 325
# 0 vertices 0 tracks 107 hits
# 0 2-tracks clusters
# 326
# 0 vertices 0 tracks 97 hits
# 0 2-tracks clusters
# 327
# 0 vertices 2 tracks 3167 hits
# 0 2-tracks clusters
# 328
# 0 vertices 0 tracks 39 hits
# 0 2-tracks clusters
# 329
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 330
# 50%
# 2 vertices 3 tracks 750 hits
# 2 2-tracks clusters
# 7 3585 71691
# ratio_charge_per_plane: 0.863923119722
# ratio_charge_per_plane: 0.93579469741
# ratio_charge_per_plane: 0.853997615525
# charge_ratio_per_plane: [0.86392311972185332, 0.93579469741041676, 0.85399761552512599]
# 7 3585 71691
# ratio_charge_per_plane: 0.900784292642
# ratio_charge_per_plane: 0.892099994832
# ratio_charge_per_plane: 0.850231103206
# charge_ratio_per_plane: [0.90078429264197835, 0.89209999483236768, 0.85023110320631512]
# 331
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 332
# 0 vertices 2 tracks 1574 hits
# 0 2-tracks clusters
# 333
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 334
# 0 vertices 1 tracks 476 hits
# 0 2-tracks clusters
# 335
# 0 vertices 1 tracks 186 hits
# 0 2-tracks clusters
# 336
# 0 vertices 2 tracks 1811 hits
# 0 2-tracks clusters
# 337
# 0 vertices 0 tracks 14 hits
# 0 2-tracks clusters
# 338
# 0 vertices 2 tracks 2423 hits
# 0 2-tracks clusters
# 339
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 340
# 52%
# 0 vertices 0 tracks 22 hits
# 0 2-tracks clusters
# 341
# 0 vertices 0 tracks 1874 hits
# 0 2-tracks clusters
# 342
# 0 vertices 0 tracks 2427 hits
# 0 2-tracks clusters
# 343
# 0 vertices 0 tracks 8 hits
# 0 2-tracks clusters
# 344
# 0 vertices 0 tracks 924 hits
# 0 2-tracks clusters
# 345
# 0 vertices 1 tracks 2954 hits
# 0 2-tracks clusters
# 346
# 0 vertices 1 tracks 140 hits
# 0 2-tracks clusters
# 347
# 0 vertices 3 tracks 492 hits
# 0 2-tracks clusters
# 348
# 0 vertices 0 tracks 98 hits
# 0 2-tracks clusters
# 349
# 1 vertices 4 tracks 2765 hits
# 1 2-tracks clusters
# 4 9826 196510
# ratio_charge_per_plane: 0.392399154647
# ratio_charge_per_plane: 0.273405447141
# ratio_charge_per_plane: 0.235635177281
# charge_ratio_per_plane: [0.39239915464734193, 0.27340544714140413, 0.23563517728095462]
# 350
# 54%
# 0 vertices 1 tracks 661 hits
# 0 2-tracks clusters
# 351
# 0 vertices 0 tracks 19 hits
# 0 2-tracks clusters
# 352
# 54%
# 0 vertices 0 tracks 122 hits
# 0 2-tracks clusters
# 353
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 354
# 0 vertices 0 tracks 99 hits
# 0 2-tracks clusters
# 355
# 1 vertices 3 tracks 532 hits
# 1 2-tracks clusters
# 4 9826 196516
# ratio_charge_per_plane: 0.7192777885
# ratio_charge_per_plane: 0.885164644697
# ratio_charge_per_plane: 0.790248826423
# charge_ratio_per_plane: [0.71927778850024393, 0.88516464469701217, 0.79024882642251981]
# 356
# 1 vertices 3 tracks 1736 hits
# 1 2-tracks clusters
# 4 9826 196517
# ratio_charge_per_plane: 0.6313547872
# ratio_charge_per_plane: 0.456809493906
# ratio_charge_per_plane: 0.461532719391
# charge_ratio_per_plane: [0.63135478720025295, 0.45680949390618653, 0.46153271939068119]
# 357
# 0 vertices 0 tracks 1317 hits
# 0 2-tracks clusters
# 358
# 0 vertices 2 tracks 1320 hits
# 0 2-tracks clusters
# 359
# 0 vertices 1 tracks 739 hits
# 0 2-tracks clusters
# 360
# 55%
# 0 vertices 1 tracks 592 hits
# 0 2-tracks clusters
# 361
# 0 vertices 1 tracks 308 hits
# 0 2-tracks clusters
# 362
# 0 vertices 3 tracks 617 hits
# 0 2-tracks clusters
# 363
# 0 vertices 0 tracks 18 hits
# 0 2-tracks clusters
# 364
# 0 vertices 0 tracks 129 hits
# 0 2-tracks clusters
# 365
# 0 vertices 1 tracks 533 hits
# 0 2-tracks clusters
# 366
# 1 vertices 2 tracks 2737 hits
# 1 2-tracks clusters
# 6 4883 97647
# ratio_charge_per_plane: 0.944264771597
# ratio_charge_per_plane: 0.876763405704
# ratio_charge_per_plane: 0.917797358894
# charge_ratio_per_plane: [0.94426477159709499, 0.87676340570356015, 0.91779735889385883]
# 367
# 0 vertices 0 tracks 76 hits
# 0 2-tracks clusters
# 368
# 0 vertices 0 tracks 87 hits
# 0 2-tracks clusters
# 369
# 1 vertices 2 tracks 1150 hits
# 1 2-tracks clusters
# 6 4883 97650
# ratio_charge_per_plane: 0.586034927405
# ratio_charge_per_plane: 0.520360395274
# ratio_charge_per_plane: 0.925334559827
# charge_ratio_per_plane: [0.58603492740536078, 0.52036039527419675, 0.92533455982716784]
# 370
# 57%
# 0 vertices 1 tracks 388 hits
# 0 2-tracks clusters
# 371
# 0 vertices 0 tracks 131 hits
# 0 2-tracks clusters
# 372
# 1 vertices 2 tracks 223 hits
# 1 2-tracks clusters
# 6 4883 97653
# ratio_charge_per_plane: 0.803531449853
# ratio_charge_per_plane: 0.426263086528
# ratio_charge_per_plane: 0.41671431802
# charge_ratio_per_plane: [0.80353144985297698, 0.42626308652844774, 0.4167143180198753]
# 373
# 0 vertices 0 tracks 2224 hits
# 0 2-tracks clusters
# 374
# 1 vertices 6 tracks 716 hits
# 1 2-tracks clusters
# 6 4883 97655
# ratio_charge_per_plane: 1.0
# ratio_charge_per_plane: 1.0
# ratio_charge_per_plane: 0.988582003071
# charge_ratio_per_plane: [1.0, 1.0, 0.98858200307072819]
# 375
# 0 vertices 0 tracks 172 hits
# 0 2-tracks clusters
# 376
# 0 vertices 0 tracks 8 hits
# 0 2-tracks clusters
# 377
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 378
# 0 vertices 2 tracks 790 hits
# 0 2-tracks clusters
# 379
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 380
# 58%
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 381
# 0 vertices 0 tracks 2209 hits
# 0 2-tracks clusters
# 382
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 383
# 0 vertices 0 tracks 2 hits
# 0 2-tracks clusters
# 384
# 59%
# 0 vertices 0 tracks 11 hits
# 0 2-tracks clusters
# 385
# 0 vertices 2 tracks 1920 hits
# 0 2-tracks clusters
# 386
# 0 vertices 0 tracks 111 hits
# 0 2-tracks clusters
# 387
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 388
# 0 vertices 0 tracks 2 hits
# 0 2-tracks clusters
# 389
# 0 vertices 0 tracks 72 hits
# 0 2-tracks clusters
# 390
# 60%
# 0 vertices 1 tracks 1097 hits
# 0 2-tracks clusters
# 391
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 392
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 393
# 0 vertices 1 tracks 2322 hits
# 0 2-tracks clusters
# 394
# 0 vertices 0 tracks 105 hits
# 0 2-tracks clusters
# 395
# 0 vertices 1 tracks 563 hits
# 0 2-tracks clusters
# 396
# 0 vertices 0 tracks 283 hits
# 0 2-tracks clusters
# 397
# 0 vertices 0 tracks 14 hits
# 0 2-tracks clusters
# 398
# 0 vertices 0 tracks 61 hits
# 0 2-tracks clusters
# 399
# 0 vertices 2 tracks 639 hits
# 0 2-tracks clusters
# 400
# 61%
# 1 vertices 4 tracks 1001 hits
# 1 2-tracks clusters
# 5 6164 123261
# ratio_charge_per_plane: 0.573430080127
# ratio_charge_per_plane: 0.98371977024
# ratio_charge_per_plane: 0.983267569357
# charge_ratio_per_plane: [0.57343008012738461, 0.9837197702395154, 0.98326756935742399]
# 401
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 402
# 0 vertices 2 tracks 755 hits
# 0 2-tracks clusters
# 403
# 0 vertices 0 tracks 159 hits
# 0 2-tracks clusters
# 404
# 0 vertices 1 tracks 2090 hits
# 0 2-tracks clusters
# 405
# 0 vertices 1 tracks 898 hits
# 0 2-tracks clusters
# 406
# 0 vertices 2 tracks 370 hits
# 0 2-tracks clusters
# 407
# 1 vertices 3 tracks 576 hits
# 1 2-tracks clusters
# 5 6164 123268
# ratio_charge_per_plane: 0.860130824965
# ratio_charge_per_plane: 0.730918368639
# ratio_charge_per_plane: 0.93771117527
# charge_ratio_per_plane: [0.8601308249651578, 0.73091836863861859, 0.93771117526999692]
# 408
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 409
# 1 vertices 3 tracks 2907 hits
# 1 2-tracks clusters
# 5 6164 123270
# ratio_charge_per_plane: 1.0
# ratio_charge_per_plane: 0.834762483864
# ratio_charge_per_plane: 0.983616413413
# charge_ratio_per_plane: [1.0, 0.83476248386362251, 0.98361641341296768]
# 410
# 63%
# 0 vertices 2 tracks 2547 hits
# 0 2-tracks clusters
# 411
# 0 vertices 2 tracks 437 hits
# 0 2-tracks clusters
# 412
# 0 vertices 1 tracks 236 hits
# 0 2-tracks clusters
# 413
# 0 vertices 0 tracks 37 hits
# 0 2-tracks clusters
# 414
# 2 vertices 4 tracks 589 hits
# 2 2-tracks clusters
# 5 6164 123275
# ratio_charge_per_plane: 0.545838147355
# ratio_charge_per_plane: 0.196373348116
# ratio_charge_per_plane: 0.379359080991
# charge_ratio_per_plane: [0.54583814735472802, 0.19637334811563883, 0.3793590809913075]
# 5 6164 123275
# ratio_charge_per_plane: 0.900643707481
# ratio_charge_per_plane: 0.965904611636
# ratio_charge_per_plane: 0.975412499799
# charge_ratio_per_plane: [0.90064370748126743, 0.96590461163555208, 0.97541249979885181]
# 415
# 3 vertices 4 tracks 1141 hits
# 3 2-tracks clusters
# 5 6164 123276
# ratio_charge_per_plane: 0.787854578961
# ratio_charge_per_plane: 0.795254544794
# ratio_charge_per_plane: 0.368997495572
# charge_ratio_per_plane: [0.78785457896111455, 0.79525454479393265, 0.3689974955718433]
# 5 6164 123276
# ratio_charge_per_plane: 0.814310100083
# ratio_charge_per_plane: 0.704123479783
# ratio_charge_per_plane: 0.683921569753
# charge_ratio_per_plane: [0.81431010008301474, 0.70412347978305534, 0.68392156975306451]
# 5 6164 123276
# ratio_charge_per_plane: 0.674955868637
# ratio_charge_per_plane: 0.650567897709
# ratio_charge_per_plane: 0.737591527276
# charge_ratio_per_plane: [0.67495586863672663, 0.65056789770867163, 0.73759152727602151]
# 416
# 64%
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 417
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 418
# 0 vertices 0 tracks 208 hits
# 0 2-tracks clusters
# 419
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 420
# 64%
# 0 vertices 1 tracks 1558 hits
# 0 2-tracks clusters
# 421
# 0 vertices 1 tracks 892 hits
# 0 2-tracks clusters
# 422
# 0 vertices 3 tracks 1142 hits
# 0 2-tracks clusters
# 423
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 424
# 0 vertices 0 tracks 34 hits
# 0 2-tracks clusters
# 425
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 426
# 0 vertices 1 tracks 240 hits
# 0 2-tracks clusters
# 427
# 1 vertices 2 tracks 348 hits
# 1 2-tracks clusters
# 6 9644 192868
# ratio_charge_per_plane: 0.463817603847
# ratio_charge_per_plane: 0.545666748018
# ratio_charge_per_plane: 0.578559353534
# charge_ratio_per_plane: [0.46381760384712317, 0.54566674801837101, 0.57855935353409249]
# 428
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 429
# 0 vertices 0 tracks 6 hits
# 0 2-tracks clusters
# 430
# 66%
# 0 vertices 0 tracks 15 hits
# 0 2-tracks clusters
# 431
# 1 vertices 3 tracks 1548 hits
# 1 2-tracks clusters
# 6 9644 192872
# ratio_charge_per_plane: 0.937788149941
# ratio_charge_per_plane: 1.0
# ratio_charge_per_plane: 0.980619585151
# charge_ratio_per_plane: [0.93778814994099702, 1.0, 0.98061958515063963]
# 432
# 0 vertices 1 tracks 826 hits
# 0 2-tracks clusters
# 433
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 434
# 0 vertices 1 tracks 834 hits
# 0 2-tracks clusters
# 435
# 0 vertices 1 tracks 1108 hits
# 0 2-tracks clusters
# 436
# 0 vertices 2 tracks 1486 hits
# 0 2-tracks clusters
# 437
# 2 vertices 3 tracks 1360 hits
# 2 2-tracks clusters
# 6 9644 192878
# ratio_charge_per_plane: 0.794219387966
# ratio_charge_per_plane: 0.954857643899
# ratio_charge_per_plane: 0.947224906402
# charge_ratio_per_plane: [0.79421938796559322, 0.95485764389862038, 0.94722490640154378]
# 6 9644 192878
# ratio_charge_per_plane: 0.607935737471
# ratio_charge_per_plane: 0.741700040034
# ratio_charge_per_plane: 0.728875482845
# charge_ratio_per_plane: [0.60793573747055341, 0.74170004003429213, 0.72887548284516257]
# 438
# 0 vertices 0 tracks 147 hits
# 0 2-tracks clusters
# 439
# 0 vertices 1 tracks 231 hits
# 0 2-tracks clusters
# 440
# 67%
# 0 vertices 0 tracks 21 hits
# 0 2-tracks clusters
# 441
# 1 vertices 2 tracks 1230 hits
# 1 2-tracks clusters
# 5 1493 29842
# ratio_charge_per_plane: 0.797134448712
# ratio_charge_per_plane: 0.97342345649
# ratio_charge_per_plane: 0.748361980573
# charge_ratio_per_plane: [0.79713444871189143, 0.97342345648987272, 0.74836198057341186]
# 442
# 0 vertices 0 tracks 22 hits
# 0 2-tracks clusters
# 443
# 1 vertices 2 tracks 253 hits
# 1 2-tracks clusters
# 5 1493 29844
# ratio_charge_per_plane: 0.908778900489
# ratio_charge_per_plane: 0.877138688928
# ratio_charge_per_plane: 0.896268089734
# charge_ratio_per_plane: [0.90877890048852816, 0.87713868892775815, 0.89626808973360994]
# 444
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 445
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 446
# 0 vertices 1 tracks 784 hits
# 0 2-tracks clusters
# 447
# 0 vertices 0 tracks 2 hits
# 0 2-tracks clusters
# 448
# 69%
# 2 vertices 4 tracks 903 hits
# 2 2-tracks clusters
# 5 1493 29849
# ratio_charge_per_plane: 1.0
# ratio_charge_per_plane: 0.931425856258
# ratio_charge_per_plane: 1.0
# charge_ratio_per_plane: [1.0, 0.93142585625784036, 1.0]
# 5 1493 29849
# ratio_charge_per_plane: 0.600144412233
# ratio_charge_per_plane: 0.507000476235
# ratio_charge_per_plane: nan
# charge_ratio_per_plane: [0.60014441223334403, 0.507000476235408, nan]
# 449
# 0 vertices 0 tracks 71 hits
# 0 2-tracks clusters
# 450
# 69%
# 0 vertices 0 tracks 94 hits
# 0 2-tracks clusters
# 451
# 2 vertices 3 tracks 1083 hits
# 2 2-tracks clusters
# 5 1493 29852
# ratio_charge_per_plane: 0.782910791851
# ratio_charge_per_plane: 0.946025271953
# ratio_charge_per_plane: 0.940520263544
# charge_ratio_per_plane: [0.78291079185054024, 0.94602527195331909, 0.94052026354391982]
# 5 1493 29852
# ratio_charge_per_plane: 0.765855634963
# ratio_charge_per_plane: 0.898933929202
# ratio_charge_per_plane: 0.941271585726
# charge_ratio_per_plane: [0.7658556349626664, 0.89893392920152693, 0.94127158572577829]
# 452
# 0 vertices 0 tracks 279 hits
# 0 2-tracks clusters
# 453
# 0 vertices 0 tracks 724 hits
# 0 2-tracks clusters
# 454
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 455
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 456
# 0 vertices 2 tracks 753 hits
# 0 2-tracks clusters
# 457
# 0 vertices 1 tracks 578 hits
# 0 2-tracks clusters
# 458
# 0 vertices 1 tracks 653 hits
# 0 2-tracks clusters
# 459
# 0 vertices 0 tracks 96 hits
# 0 2-tracks clusters
# 460
# 70%
# 0 vertices 0 tracks 33 hits
# 0 2-tracks clusters
# 461
# 1 vertices 3 tracks 1431 hits
# 1 2-tracks clusters
# 4 5883 117642
# ratio_charge_per_plane: 0.124403010809
# ratio_charge_per_plane: 0.394312362399
# ratio_charge_per_plane: 0.281172787667
# charge_ratio_per_plane: [0.12440301080935359, 0.39431236239891054, 0.2811727876667916]
# 462
# 0 vertices 0 tracks 396 hits
# 0 2-tracks clusters
# 463
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 464
# 0 vertices 1 tracks 313 hits
# 0 2-tracks clusters
# 465
# 0 vertices 1 tracks 1537 hits
# 0 2-tracks clusters
# 466
# 0 vertices 0 tracks 66 hits
# 0 2-tracks clusters
# 467
# 0 vertices 1 tracks 418 hits
# 0 2-tracks clusters
# 468
# 0 vertices 0 tracks 534 hits
# 0 2-tracks clusters
# 469
# 0 vertices 0 tracks 770 hits
# 0 2-tracks clusters
# 470
# 72%
# 0 vertices 0 tracks 43 hits
# 0 2-tracks clusters
# 471
# 0 vertices 0 tracks 19 hits
# 0 2-tracks clusters
# 472
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 473
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 474
# 0 vertices 0 tracks 24 hits
# 0 2-tracks clusters
# 475
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 476
# 0 vertices 2 tracks 227 hits
# 0 2-tracks clusters
# 477
# 0 vertices 0 tracks 166 hits
# 0 2-tracks clusters
# 478
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 479
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 480
# 73%
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 481
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 482
# 0 vertices 2 tracks 1840 hits
# 0 2-tracks clusters
# 483
# 0 vertices 0 tracks 185 hits
# 0 2-tracks clusters
# 484
# 0 vertices 2 tracks 1204 hits
# 0 2-tracks clusters
# 485
# 0 vertices 0 tracks 124 hits
# 0 2-tracks clusters
# 486
# 0 vertices 1 tracks 533 hits
# 0 2-tracks clusters
# 487
# 0 vertices 0 tracks 84 hits
# 0 2-tracks clusters
# 488
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 489
# 0 vertices 2 tracks 989 hits
# 0 2-tracks clusters
# 490
# 75%
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 491
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 492
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 493
# 0 vertices 1 tracks 284 hits
# 0 2-tracks clusters
# 494
# 0 vertices 0 tracks 53 hits
# 0 2-tracks clusters
# 495
# 0 vertices 0 tracks 73 hits
# 0 2-tracks clusters
# 496
# 0 vertices 1 tracks 930 hits
# 0 2-tracks clusters
# 497
# 0 vertices 0 tracks 44 hits
# 0 2-tracks clusters
# 498
# 0 vertices 1 tracks 84 hits
# 0 2-tracks clusters
# 499
# 0 vertices 0 tracks 130 hits
# 0 2-tracks clusters
# 500
# 76%
# 0 vertices 1 tracks 860 hits
# 0 2-tracks clusters
# 501
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 502
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 503
# 0 vertices 1 tracks 217 hits
# 0 2-tracks clusters
# 504
# 0 vertices 0 tracks 82 hits
# 0 2-tracks clusters
# 505
# 0 vertices 1 tracks 131 hits
# 0 2-tracks clusters
# 506
# 0 vertices 3 tracks 625 hits
# 0 2-tracks clusters
# 507
# 0 vertices 0 tracks 9 hits
# 0 2-tracks clusters
# 508
# 0 vertices 2 tracks 1435 hits
# 0 2-tracks clusters
# 509
# 1 vertices 3 tracks 1423 hits
# 1 2-tracks clusters
# 1 2026 40510
# ratio_charge_per_plane: 0.88714479631
# ratio_charge_per_plane: 0.668689043477
# ratio_charge_per_plane: 0.845468925379
# charge_ratio_per_plane: [0.88714479630997245, 0.66868904347692715, 0.84546892537944562]
# 510
# 78%
# 0 vertices 2 tracks 1059 hits
# 0 2-tracks clusters
# 511
# 0 vertices 1 tracks 107 hits
# 0 2-tracks clusters
# 512
# 78%
# 0 vertices 0 tracks 626 hits
# 0 2-tracks clusters
# 513
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 514
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 515
# 0 vertices 0 tracks 28 hits
# 0 2-tracks clusters
# 516
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 517
# 1 vertices 3 tracks 806 hits
# 1 2-tracks clusters
# 1 2026 40518
# ratio_charge_per_plane: 0.967201391748
# ratio_charge_per_plane: 0.729102469496
# ratio_charge_per_plane: 0.905091752069
# charge_ratio_per_plane: [0.96720139174751951, 0.72910246949591784, 0.90509175206895431]
# 518
# 0 vertices 1 tracks 321 hits
# 0 2-tracks clusters
# 519
# 1 vertices 2 tracks 830 hits
# 1 2-tracks clusters
# 1 2026 40520
# ratio_charge_per_plane: 0.884925472981
# ratio_charge_per_plane: 0.900942897902
# ratio_charge_per_plane: 0.889493319166
# charge_ratio_per_plane: [0.88492547298105606, 0.90094289790166304, 0.88949331916561858]
# 520
# 80%
# 0 vertices 1 tracks 426 hits
# 0 2-tracks clusters
# 521
# 1 vertices 2 tracks 384 hits
# 1 2-tracks clusters
# 7 4317 86322
# ratio_charge_per_plane: 0.995799385209
# ratio_charge_per_plane: 0.96086416331
# ratio_charge_per_plane: 0.963157503875
# charge_ratio_per_plane: [0.99579938520894806, 0.96086416330990343, 0.96315750387482824]
# 522
# 0 vertices 1 tracks 2002 hits
# 0 2-tracks clusters
# 523
# 0 vertices 0 tracks 132 hits
# 0 2-tracks clusters
# 524
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 525
# 0 vertices 2 tracks 733 hits
# 0 2-tracks clusters
# 526
# 0 vertices 0 tracks 88 hits
# 0 2-tracks clusters
# 527
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 528
# 0 vertices 1 tracks 922 hits
# 0 2-tracks clusters
# 529
# 0 vertices 0 tracks 9 hits
# 0 2-tracks clusters
# 530
# 81%
# 0 vertices 0 tracks 40 hits
# 0 2-tracks clusters
# 531
# 0 vertices 1 tracks 44 hits
# 0 2-tracks clusters
# 532
# 0 vertices 0 tracks 2678 hits
# 0 2-tracks clusters
# 533
# 1 vertices 3 tracks 687 hits
# 1 2-tracks clusters
# 7 4317 86334
# ratio_charge_per_plane: 0.805367413886
# ratio_charge_per_plane: 0.819911406653
# ratio_charge_per_plane: 0.815386458943
# charge_ratio_per_plane: [0.80536741388647159, 0.8199114066528409, 0.81538645894298645]
# 534
# 1 vertices 4 tracks 1698 hits
# 1 2-tracks clusters
# 7 4317 86335
# ratio_charge_per_plane: 0.979549896198
# ratio_charge_per_plane: 1.0
# ratio_charge_per_plane: 0.997440189192
# charge_ratio_per_plane: [0.97954989619802313, 1.0, 0.99744018919176836]
# 535
# 0 vertices 0 tracks 4 hits
# 0 2-tracks clusters
# 536
# 0 vertices 0 tracks 12 hits
# 0 2-tracks clusters
# 537
# 0 vertices 0 tracks 8 hits
# 0 2-tracks clusters
# 538
# 0 vertices 1 tracks 2142 hits
# 0 2-tracks clusters
# 539
# 0 vertices 4 tracks 1622 hits
# 0 2-tracks clusters
# 540
# 83%
# 0 vertices 0 tracks 11 hits
# 0 2-tracks clusters
# 541
# 0 vertices 0 tracks 43 hits
# 0 2-tracks clusters
# 542
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 543
# 0 vertices 0 tracks 30 hits
# 0 2-tracks clusters
# 544
# 83%
# 1 vertices 4 tracks 1340 hits
# 1 2-tracks clusters
# 5 8065 161285
# ratio_charge_per_plane: 0.666513961922
# ratio_charge_per_plane: 0.366754823438
# ratio_charge_per_plane: 0.267663114676
# charge_ratio_per_plane: [0.66651396192218171, 0.36675482343813204, 0.26766311467606402]
# 545
# 0 vertices 0 tracks 46 hits
# 0 2-tracks clusters
# 546
# 0 vertices 0 tracks 38 hits
# 0 2-tracks clusters
# 547
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 548
# 0 vertices 1 tracks 1071 hits
# 0 2-tracks clusters
# 549
# 0 vertices 2 tracks 565 hits
# 0 2-tracks clusters
# 550
# 84%
# 0 vertices 2 tracks 616 hits
# 0 2-tracks clusters
# 551
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 552
# 0 vertices 1 tracks 713 hits
# 0 2-tracks clusters
# 553
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 554
# 0 vertices 0 tracks 20 hits
# 0 2-tracks clusters
# 555
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 556
# 0 vertices 1 tracks 562 hits
# 0 2-tracks clusters
# 557
# 0 vertices 4 tracks 701 hits
# 0 2-tracks clusters
# 558
# 0 vertices 1 tracks 735 hits
# 0 2-tracks clusters
# 559
# 0 vertices 0 tracks 21 hits
# 0 2-tracks clusters
# 560
# 86%
# 0 vertices 0 tracks 314 hits
# 0 2-tracks clusters
# 561
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 562
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 563
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 564
# 0 vertices 0 tracks 5 hits
# 0 2-tracks clusters
# 565
# 1 vertices 2 tracks 2107 hits
# 1 2-tracks clusters
# 4 8995 179886
# ratio_charge_per_plane: 0.882172130383
# ratio_charge_per_plane: 0.939879777106
# ratio_charge_per_plane: 0.940344050029
# charge_ratio_per_plane: [0.8821721303826886, 0.93987977710557302, 0.94034405002888855]
# 566
# 0 vertices 1 tracks 1758 hits
# 0 2-tracks clusters
# 567
# 0 vertices 3 tracks 995 hits
# 0 2-tracks clusters
# 568
# 0 vertices 1 tracks 385 hits
# 0 2-tracks clusters
# 569
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 570
# 87%
# 0 vertices 0 tracks 4 hits
# 0 2-tracks clusters
# 571
# 0 vertices 0 tracks 153 hits
# 0 2-tracks clusters
# 572
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 573
# 0 vertices 1 tracks 486 hits
# 0 2-tracks clusters
# 574
# 0 vertices 2 tracks 892 hits
# 0 2-tracks clusters
# 575
# 0 vertices 0 tracks 11 hits
# 0 2-tracks clusters
# 576
# 88%
# 0 vertices 0 tracks 6 hits
# 0 2-tracks clusters
# 577
# 1 vertices 4 tracks 891 hits
# 1 2-tracks clusters
# 4 8995 179898
# ratio_charge_per_plane: 0.962981493733
# ratio_charge_per_plane: 0.636812185176
# ratio_charge_per_plane: 0.49393860777
# charge_ratio_per_plane: [0.96298149373300745, 0.63681218517645821, 0.49393860776974907]
# 578
# 0 vertices 1 tracks 219 hits
# 0 2-tracks clusters
# 579
# 0 vertices 0 tracks 519 hits
# 0 2-tracks clusters
# 580
# 89%
# 0 vertices 1 tracks 1439 hits
# 0 2-tracks clusters
# 581
# 0 vertices 3 tracks 1659 hits
# 0 2-tracks clusters
# 582
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 583
# 0 vertices 1 tracks 718 hits
# 0 2-tracks clusters
# 584
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 585
# 0 vertices 0 tracks 39 hits
# 0 2-tracks clusters
# 586
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 587
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 588
# 0 vertices 0 tracks 53 hits
# 0 2-tracks clusters
# 589
# 0 vertices 0 tracks 248 hits
# 0 2-tracks clusters
# 590
# 90%
# 0 vertices 1 tracks 121 hits
# 0 2-tracks clusters
# 591
# 0 vertices 1 tracks 1575 hits
# 0 2-tracks clusters
# 592
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 593
# 0 vertices 0 tracks 21 hits
# 0 2-tracks clusters
# 594
# 0 vertices 0 tracks 52 hits
# 0 2-tracks clusters
# 595
# 0 vertices 0 tracks 28 hits
# 0 2-tracks clusters
# 596
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 597
# 0 vertices 1 tracks 701 hits
# 0 2-tracks clusters
# 598
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 599
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 600
# 92%
# 2 vertices 3 tracks 407 hits
# 2 2-tracks clusters
# 4 5837 116721
# ratio_charge_per_plane: 0.992907075125
# ratio_charge_per_plane: 0.947681407535
# ratio_charge_per_plane: 0.800355480052
# charge_ratio_per_plane: [0.99290707512516596, 0.9476814075351323, 0.80035548005173807]
# 4 5837 116721
# ratio_charge_per_plane: 0.9901120117
# ratio_charge_per_plane: 0.927668668953
# ratio_charge_per_plane: 0.835383982026
# charge_ratio_per_plane: [0.99011201169954777, 0.927668668953196, 0.83538398202618236]
# 601
# 0 vertices 0 tracks 263 hits
# 0 2-tracks clusters
# 602
# 0 vertices 0 tracks 123 hits
# 0 2-tracks clusters
# 603
# 1 vertices 3 tracks 586 hits
# 1 2-tracks clusters
# 4 5837 116724
# ratio_charge_per_plane: 0.574538509889
# ratio_charge_per_plane: 0.680584224784
# ratio_charge_per_plane: 0.77599534078
# charge_ratio_per_plane: [0.5745385098885355, 0.68058422478358283, 0.77599534077957144]
# 604
# 0 vertices 1 tracks 743 hits
# 0 2-tracks clusters
# 605
# 0 vertices 0 tracks 725 hits
# 0 2-tracks clusters
# 606
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 607
# 0 vertices 0 tracks 28 hits
# 0 2-tracks clusters
# 608
# 93%
# 0 vertices 0 tracks 793 hits
# 0 2-tracks clusters
# 609
# 1 vertices 2 tracks 557 hits
# 1 2-tracks clusters
# 4 5837 116730
# ratio_charge_per_plane: 0.950013641626
# ratio_charge_per_plane: 0.901843894434
# ratio_charge_per_plane: 0.962332056241
# charge_ratio_per_plane: [0.95001364162598612, 0.90184389443433244, 0.9623320562414367]
# 610
# 93%
# 0 vertices 0 tracks 1835 hits
# 0 2-tracks clusters
# 611
# 0 vertices 2 tracks 637 hits
# 0 2-tracks clusters
# 612
# 0 vertices 0 tracks 62 hits
# 0 2-tracks clusters
# 613
# 0 vertices 1 tracks 232 hits
# 0 2-tracks clusters
# 614
# 0 vertices 1 tracks 424 hits
# 0 2-tracks clusters
# 615
# 0 vertices 0 tracks 23 hits
# 0 2-tracks clusters
# 616
# 0 vertices 0 tracks 2 hits
# 0 2-tracks clusters
# 617
# 0 vertices 2 tracks 655 hits
# 0 2-tracks clusters
# 618
# 0 vertices 0 tracks 139 hits
# 0 2-tracks clusters
# 619
# 0 vertices 1 tracks 808 hits
# 0 2-tracks clusters
# 620
# 95%
# 0 vertices 0 tracks 599 hits
# 0 2-tracks clusters
# 621
# 0 vertices 2 tracks 354 hits
# 0 2-tracks clusters
# 622
# 0 vertices 3 tracks 934 hits
# 0 2-tracks clusters
# 623
# 1 vertices 3 tracks 899 hits
# 1 2-tracks clusters
# 6 678 13544
# ratio_charge_per_plane: 0.975666379852
# ratio_charge_per_plane: 0.924807669862
# ratio_charge_per_plane: 0.950072189694
# charge_ratio_per_plane: [0.97566637985189197, 0.92480766986153562, 0.95007218969381491]
# 624
# 0 vertices 1 tracks 167 hits
# 0 2-tracks clusters
# 625
# 0 vertices 0 tracks 54 hits
# 0 2-tracks clusters
# 626
# 0 vertices 2 tracks 1360 hits
# 0 2-tracks clusters
# 627
# 1 vertices 2 tracks 620 hits
# 1 2-tracks clusters
# 6 678 13548
# ratio_charge_per_plane: 0.990645237026
# ratio_charge_per_plane: 0.941316363221
# ratio_charge_per_plane: 1.0
# charge_ratio_per_plane: [0.99064523702575724, 0.94131636322142265, 1.0]
# 628
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 629
# 0 vertices 2 tracks 459 hits
# 0 2-tracks clusters
# 630
# 96%
# 0 vertices 0 tracks 35 hits
# 0 2-tracks clusters
# 631
# 1 vertices 3 tracks 417 hits
# 1 2-tracks clusters
# 6 678 13552
# ratio_charge_per_plane: 0.946323394523
# ratio_charge_per_plane: 1.0
# ratio_charge_per_plane: 0.776435172326
# charge_ratio_per_plane: [0.94632339452330183, 1.0, 0.77643517232591996]
# 632
# 0 vertices 0 tracks 48 hits
# 0 2-tracks clusters
# 633
# 0 vertices 1 tracks 1229 hits
# 0 2-tracks clusters
# 634
# 0 vertices 1 tracks 1226 hits
# 0 2-tracks clusters
# 635
# 0 vertices 2 tracks 1697 hits
# 0 2-tracks clusters
# 636
# 0 vertices 0 tracks 2019 hits
# 0 2-tracks clusters
# 637
# 0 vertices 0 tracks 44 hits
# 0 2-tracks clusters
# 638
# 0 vertices 0 tracks 59 hits
# 0 2-tracks clusters
# 639
# 3 vertices 9 tracks 3795 hits
# 3 2-tracks clusters
# 6 678 13560
# ratio_charge_per_plane: 0.246232734817
# ratio_charge_per_plane: 0.413782590254
# ratio_charge_per_plane: 0.389724826231
# charge_ratio_per_plane: [0.24623273481726846, 0.41378259025371161, 0.38972482623072963]
# 6 678 13560
# ratio_charge_per_plane: 0.738587867697
# ratio_charge_per_plane: 0.782648102212
# ratio_charge_per_plane: 0.705722605574
# charge_ratio_per_plane: [0.73858786769684914, 0.78264810221157388, 0.70572260557353217]
# 6 678 13560
# ratio_charge_per_plane: 1.0
# ratio_charge_per_plane: 0.924448390937
# ratio_charge_per_plane: 0.856121053345
# charge_ratio_per_plane: [1.0, 0.92444839093718822, 0.85612105334462452]
# 640
# 98%
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 641
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 642
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 643
# 0 vertices 0 tracks 902 hits
# 0 2-tracks clusters
# 644
# 0 vertices 0 tracks 1858 hits
# 0 2-tracks clusters
# 645
# 0 vertices 2 tracks 636 hits
# 0 2-tracks clusters
# 646
# 0 vertices 0 tracks 813 hits
# 0 2-tracks clusters
# 647
# 0 vertices 0 tracks 0 hits
# 0 2-tracks clusters
# 648
# 0 vertices 1 tracks 200 hits
# 0 2-tracks clusters
# 649
# 0 vertices 2 tracks 667 hits
# 0 2-tracks clusters
# 650
# 99%
# 0 vertices 1 tracks 784 hits
# 0 2-tracks clusters
# 651
# 0 vertices 1 tracks 2004 hits
# 0 2-tracks clusters
# 652
# 0 vertices 2 tracks 1213 hits
# 0 2-tracks clusters
# 653
# 0 vertices 1 tracks 2564 hits
# 0 2-tracks clusters
# done.

# %%
# fig,ax=plt.subplots(figsize=(14,10))
# bins=np.linspace(0,1,100)
# plt.hist(ratio_charge_true_cc1p,bins=bins,histtype='step',label='true CC1p',linewidth=3,normed=1);
# plt.hist(ratio_charge_NonTrueCC1p1mu1p,bins=bins,histtype='step',label='1$\\mu$-1p, non true CC1p',linewidth=3,normed=1);
# plt.hist(ratio_charge_Non1mu1p,bins=bins,histtype='step',label='non 1$\\mu$-1p',linewidth=3,normed=1);
# set_axes(ax,x_label='tracks-associated $\\Delta Q$/ total $\\Delta Q$ deposited')
# plt.legend(loc='upper right',fontsize=25)#, bbox_to_anchor=(1, 0.5))
# plt.tight_layout()
ratio_charge_Non1mu1p
# Out:
# [0.77757925297070452,
#  0.65680592475042632,
#  0.55555852340169054,
#  0.86620809002969568,
#  0.56381939918295254,
#  0.73939106599986804,
#  0.87846783683796925,
#  0.79949133000824713,
#  0.81272677622410605,
#  0.91733624597853458,
#  0.91962531072407883,
#  0.90847975122126245,
#  0.86105330975990213,
#  0.26017329082357327,
#  0.81261849573648293,
#  0.58701346780763963,
#  0.43259265971372968,
#  0.58253101050913347,
#  0.82390561352540848,
#  nan,
#  0.65160839381799074,
#  0.51385731075867069,
#  0.73992145041754676,
#  0.38892561138608911,
#  0.67818151756720768,
#  0.57810875079248192,
#  0.88457181088579873,
#  0.88103846356022031,
#  0.3004799263565669,
#  0.7982304198732586,
#  0.51656566683237359,
#  0.54883628480043334,
#  0.99619400102357603,
#  0.84680580657477467,
#  0.84292012295792451,
#  0.93945963242552999,
#  0.37385685882055814,
#  0.94732027297189048,
#  0.65070220644229682,
#  0.73411838320637823,
#  0.68770509787380663,
#  0.52934790179986224,
#  0.97280257836387884,
#  0.692837086783336,
#  0.83963996192505874,
#  0.9771419520859469,
#  nan,
#  0.86868704996332402,
#  0.26662938695835187,
#  0.80043425505544841,
#  0.8917872300161126,
#  0.97327368413122661,
#  0.81355509316076624,
#  0.43364396667879257,
#  0.69791076222640491,
#  0.91364798757067878,
#  0.91772155422630863,
#  0.67703935848389651,
#  0.93806319743391853,
#  0.9501820798024142,
#  0.90758618894974052,
#  0.34991338376723657,
#  0.74231952516065169,
#  0.92685648142727095]
