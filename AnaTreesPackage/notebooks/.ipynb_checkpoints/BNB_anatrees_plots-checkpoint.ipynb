# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('/Users/erezcohen/Desktop/uBoone/AnalysisTreesAna/PassedGBDTFiles/BNB_TrainedOn_only_MC_BNB/passedGBDT_BNB_5e19POT_BNB_TrainedOn_only_MC_BNB_allscores_features.csv')
data
# Out:
#          Unnamed: 0   run  subrun  event  trackid  flip  nhits     length  \
# 0                 0  5938       2    101        0     0    904  175.36900
# 1                 1  5938       2    101        1     0    839  148.32000
# 2                 2  5938       2    102        2     0    988  252.11900
# 3                 3  5938       2    102        3     0    440  127.06300
# 4                 4  5938       2    102        4     0    368   82.66220
# 5                 5  5938       2    102        7     1     55   10.06810
# 6                 6  5938       2    103        0     0   1433  277.92900
# 7                 7  5938       2    103        1     0   1165  267.81500
# 8                 8  5938       2    103        2     0    796  140.24800
# 9                 9  5938       2    103        6     0     50   23.96310
# 10               10  5938       2    105        1     0    321   87.11110
# 11               11  5938       2    105        4     0     35   14.56980
# ...

# %%
data_maxprotons = data[data.MCpdgCode==2212]
data_maxmuon = data[data.MCpdgCode!=2212]

# %%
bins = np.linspace(0,50,50)
plt.hist(data_protons.pidpida[data_protons.pidpida<100],bins=bins,color='blue',histtype='step',label='MC protons')
plt.hist(data_nonprotons.pidpida[data_nonprotons.pidpida<100],bins=bins,color='green',histtype='step',label='MC non protons')
plt.legend()
