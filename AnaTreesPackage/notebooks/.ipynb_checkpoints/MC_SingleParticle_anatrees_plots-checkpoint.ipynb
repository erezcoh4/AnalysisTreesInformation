# %% [markdown]
# # imports

# %%
from notebooks_tools import *
# %matplotlib inline

# %% [markdown]
# # load MC tracks

# %%
MC_protons = pd.read_csv('/Users/erezcohen/Desktop/uBoone/AnalysisTreesAna/FeaturesFiles/full_features_p_0.02-1.5GeV_isotropic_AnalysisTrees.csv')

# %%
pt.plot_1d_hist(180/3.1415*MC_protons.truth_theta,bins=50,histtype='bar',xlabel='$\\theta$ [deg.]')

# %%
pt.plot_2d_hist(180/3.1415*data_protons.theta,data_protons.Ev_truth,xlabel='$\\theta$ [deg.]',ylabel='truth $\\E_{\\nu}$ [MeV]')

# %%
data_protons
# Out:
#         run  subrun   event  trackid  flip  nhits      length     startx  \
# 1         4    4255   85082        2     1     20    4.569580  165.00000
# 5         4    4255   85085        1     0     94   16.817600  212.89400
# 6         4    4255   85085        2     0     83   15.478200  205.47500
# 10        4    4255   85087        2     0      1    0.634294  144.15000
# 12        4    4255   85090        1     0    120   19.604700   48.61150
# 13        4    4255   85092        0     0    250   53.131200   29.05640
# 14        4    4255   85092        1     0    235   50.852000   41.81930
# 15        4    4255   85092        2     1     40    7.701390   73.13590
# 16        4    4255   85096        1     0     64   10.337100  195.69000
# 20        5    5752  115024        1     1      3    3.951190  187.80600
# 21        5    5752  115032        1     0     76   14.711800    5.93935
# 22        5    5752  115038        1     0     30    8.727650   16.01890
# ...
